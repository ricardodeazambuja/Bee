# %% [markdown]
# # In this notebook I'm generating the movements and the states variables (torques and angles) in order to produce this movement using the 2dof simulator.
#
# ### Some of the algorithms (or inspiration) to simulate the 2dof arm came from: http://www.gribblelab.org/compneuro/

# %% [markdown]
# # Here starts the 2 joint arm study

# %% [markdown]
# # Main functions to the 2 joint arm simulation

# %%
# Makes possible to show the output from matplotlib inline
# %matplotlib inline
import matplotlib.pyplot as plt

# Makes the figures in the PNG format:
# For more information see %config InlineBackend
# %config InlineBackend.figure_formats=set([u'png'])

plt.rcParams['figure.figsize'] = 20, 10

import numpy
import sys
import save_load_file as slf

import os

# %%
import matplotlib 

# font = {'family' : 'normal',
#         'weight' : 'bold',
#         'size'   : 22}

font = {'weight' : 'normal',
        'size'   : 20}

matplotlib.rc('font', **font)

# matplotlib.rcdefaults() # restores to the default values

# http://matplotlib.org/api/matplotlib_configuration_api.html#matplotlib.rc

# %%
from simulation_2DoF_Arm_physics import *
reload(sys.modules['simulation_2DoF_Arm_physics']) # Makes sure the interpreter is going to reload the module
# Out:
# <module 'simulation_2DoF_Arm_physics' from 'simulation_2DoF_Arm_physics.pyc'>

# %% [markdown]
# ## End of the main functions!

# %% [markdown]
# # Step-by-step of how to generate the values to the simulations:

# %%
# First the arm parametres according to Joshi/Maass paper
aparams = {
    'l1' : 0.5, # metres
    'l2' : 0.5,
    'lc1' : 0.25,
    'lc2' : 0.25,
    'm1' : 1.0, # kg
    'm2' : 1.0,
    'i1' : 0.03, # kg*m*m
    'i2' : 0.03
}

# %%
sim_set = "set_00"
base_dir = "2DofArm_simulation_data"

trajectories = [[[0.75,0.25],[0.0,0.5]], [[0.25,0.60],[-0.25,0.60]], [[-0.10,0.75],[-0.10,0.25]],[[-0.75,0.50],[-0.40,0.00]]]
tji = 2
xstart,ystart = trajectories[tji-1][0]
xdest,ydest = trajectories[tji-1][1]

# Total time spent during the movement (in seconds)
MT = 0.5
# Simulation time step (in seconds)
time_step = 2/1000.0
# Number of neurons at the input layer (defines the resolution of the system)
Ninput = 50

# %%
trajectories[tji-1]
# Out:
# [[0.25, 0.6], [-0.25, 0.6]]

# %%
t_mov=numpy.arange(0, MT, time_step) # t starts in 0s and steps time_step(s) until reaches MT(s)

# Generates the movements according to:
# Flash, Tamar, and Neville Hogan. 1985
H_path=cartesian_movement_generation_training(xstart, ystart, xdest, ydest, MT, t_mov)

# These are the values teta1 and teta2 can have because the system limits the resolution.
# According to Joshi/Maass paper there are 50 neurons to code the positions of each variable.
#
#
teta1=numpy.linspace(-numpy.pi/6,numpy.pi,num=Ninput)
teta2=numpy.linspace(0,numpy.pi,num=Ninput)
teta1_teta2 = numpy.array([teta1,teta2]).T # This is the matrix to use with the function
                                           # to generate the x,y values of the workspace
    
# Joint's workspace: all the possible combinations between teta1 and teta2.
teta_workspace = numpy.array([[t1,t2] for t1 in teta1 for t2 in teta2])

# Arm's workspace: x,y points that the arm (endpoint) can reach
H_workspace = joints_to_hand(teta_workspace,aparams)[0] # I'm getting the first because it returns the elbow's positions too.

# %%
# # As can be seen in the figure below, the ORIGINAL CONTINUOUS generated movement is smooth because it don't have to obey the 
# # maximum precision of the joints as in a real system. In a real system the joints cannot move continuously because
# # normally at least the encoder generates a discrete sequence of values only.

# plt.figure(figsize=(20,10))
# # plt.plot(t_mov,numpy.sqrt(H_path[:,0]**2+H_path[:,1]**2), label="Resultant Movement Vector")
# plt.plot(t_mov,numpy.sqrt(numpy.concatenate(([0], derivator(H_path[:,0],t_mov)))**2+numpy.concatenate(([0], derivator(H_path[:,1],t_mov)))**2),label="Resultant Velocity Vector")
# plt.title("Endpoint Gaussian Velocity - Trajectory " + str(tji))
# plt.xlabel("time (s)")
# plt.ylabel("velocity (m/s)")
# plt.xlim(t_mov[0],t_mov[-1])
# # plt.legend()
# plt.savefig(os.getcwd()+"/"+base_dir+"/"+"endpoint_cartesian_velocity_trajectory_"+str(tji)+".pdf")
# plt.show()

# %%
# # Here I'm plotting the possible points the endpoint could reach if:
# # Joint 0: [-Pi/6 to Pi, but using only 50 divisions]
# # Joint 1: [0 to Pi, but using only 50 divisions]
# plt.figure(figsize=(20,20))
# plt.plot(H_workspace[:,0],H_workspace[:,1],'k.',markersize=2)
# plt.title("Arm's discretized workspace")
# plt.xlabel("x (m)")
# plt.ylabel("y (m)")
# plt.xlim(-1,1)
# plt.ylim(-1,1)
# plt.savefig(os.getcwd()+"/"+base_dir+"/"+"workspace.pdf")
# plt.show()

# %% [markdown]
# # Automatic generation of random valid trajectories:

# %%
# # HERE I WANT TO GENERATE SOME RANDOM TRAJECTORIES.
# # I'M GOING TO USE THE POINTS FROM THE WORKSPACE FOR THIS.
# # I DON'T WANT TO REPEAT THE TRAJECTORIES.
# NoT = 40
# max_trials = 1000
# trajectories = []
# trials = 0
# while((len(trajectories)<NoT) and (trials<max_trials)):
#     new_traj = numpy.random.randint(1,H_workspace.shape[0],size=2)
#     if not(new_traj[0]==new_traj[1]).all():
#         trajectories.append([new_traj[0],new_traj[1]])
#     trials+=1

# %%
# And this is the final list with the format [[[start_x,start_y],[dest_x,dest_y]],...]
# [[H_workspace[i[0]].tolist(),H_workspace[i[1]].tolist()] for i in trajectories]

# %%
# Now I need to fit the H values using the H_workspace ones!
# What I'm doing here is: I fit the value to the nearest X and Y (individualy) available in the workspace matrix.
# H_corrected = numpy.array([[H_workspace[:,0][abs(H_workspace[:,0]-xy[0]).argmin()], H_workspace[:,1][abs(H_workspace[:,1]-xy[1]).argmin()]] for xy in H_path])
# numpy.linalg.norm(H_workspace,axis=1)
# numpy.linalg.norm(H_workspace-numpy.array([0,1]),axis=1).argmin()

H_corrected=numpy.array([H_workspace[numpy.linalg.norm(H_workspace-xy,axis=1).argmin()] for xy in H_path]);

# %% [markdown]
# ##Here we can see one limitation of an input code that is made os discrete values.
# It's impossible to generate the joint torques for this values because there are too many abrupt changes that would demand huge accelerations.

# %%
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(111)
plt.plot(H_corrected[:,0],H_corrected[:,1],'bv-',markersize=4, label="Discrete workspace")
plt.plot(H_path[:,0],H_path[:,1],'r.-',markersize=2, label="Continuous workspace")

plt.plot(H_path[0,0],H_path[0,1], 'bo',markersize=15)
plt.plot(H_path[-1,0],H_path[-1,1], 'bo',markersize=15)

ax.text(H_path[0,0], H_path[0,1],'Start ('+"{0:.2f}".format(H_path[0,0])+','+"{0:.2f}".format(H_path[0,1])+')',
        verticalalignment='bottom', horizontalalignment='left',
        color='blue', fontsize=30)

ax.text(H_path[-1,0]-0.03, H_path[-1,1]-0.03,'End ('+"{0:.2f}".format(H_path[-1,0])+','+"{0:.2f}".format(H_path[-1,1])+')',
        verticalalignment='top', horizontalalignment='right',
        color='blue', fontsize=30)

plt.title("Trajectory " + str(tji))
plt.xlabel("x (m)")
plt.ylabel("y (m)")
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.legend(loc=4)
plt.savefig(os.getcwd()+"/"+base_dir+"/"+"cartesian_space_trajectory_"+str(tji)+".pdf")
plt.show()

# %% [markdown]
# # But, maybe, we could ignore this behaviour because the LSM is going to act as a filter and even with a discrete input code scheme the output can still be a analog variable.

# %%
# # Generate the joint's positions according to the fitted (X,Y) values.
# # I'm using the traditional geometric way to do the inverse kinematics here. I need to
# # implement the minimum jerk way to generate the joint's positions taking into account the movement's dynamics.
Joints_ws=hand_to_joints(H_corrected, aparams,ang_error=0.1)

# # Here "fitted" means positions that are actually possible to be reached using the discrete values available to
# # the two joints (the neuron code limits the joint's angles in 50 different values)

# %%
# Generate the joint's positions according to the CONTINUOS (X,Y) values.
# I'm using the traditional geometric way to do the inverse kinematics here. I need to
# implement the minimum jerk way to generate the joint's positions taking into account the movement's dynamics.

Joints=hand_to_joints(H_path, aparams, ang_error=0.1)

# %%
# Here I'm extending the Joints matrix because I need two extra positions to calculate the accelerations.
# Consequently, because the trajectory always finish with velocity ZERO, keeping the same position seems a good choice. 
Joints_extended=numpy.concatenate((Joints,[Joints[-1],Joints[-1]]))

Joints_ws_extended=numpy.concatenate((Joints_ws,[Joints_ws[-1],Joints_ws[-1]]))

# But the time array (t_mov) must be extended too:
t_mov_extended=numpy.concatenate((t_mov,[t_mov[-1]+time_step],[t_mov[-1]+2*time_step]))

# %%
# H_plot_ws,E_plot_ws=joints_to_hand(Joints_ws, aparams) # Generates the data used to draw the arm using the valid joint positions
# H_plot,E_plot=joints_to_hand(Joints, aparams) # Generates the data used to draw the arm using the valid joint positions

# step_plot = 15

# plt.figure(figsize=(20,10))
# plt.plot(H_plot_ws[:,0],H_plot_ws[:,1],'k.-')
# for i in range(0,len(E_plot_ws),step_plot):
#     plt.plot((0,E_plot_ws[i,0],H_plot_ws[i,0]),(0,E_plot_ws[i,1],H_plot_ws[i,1]),'b-')
# plt.title("Arm generating the trajectory (discrete workspace) - Trajectory " + str(tji))
# plt.xlabel("x (m)")
# plt.ylabel("y (m)")
# plt.xlim(-1,1)
# plt.ylim(-1,1)
# plt.savefig(os.getcwd()+"/"+base_dir+"/"+"discrete_workspace_trajectory_"+str(tji)+".pdf")
# plt.show()

# %%
H_plot_ws,E_plot_ws=joints_to_hand(Joints_ws, aparams) # Generates the data used to draw the arm using the valid joint positions
H_plot,E_plot=joints_to_hand(Joints, aparams) # Generates the data used to draw the arm using the valid joint positions

step_plot = 15

plt.figure(figsize=(20,10))
plt.plot(H_plot[:,0],H_plot[:,1],'k.-')
for i in range(0,len(E_plot),step_plot):
    plt.plot((0,E_plot[i,0],H_plot[i,0]),(0,E_plot[i,1],H_plot[i,1]),'b-')
plt.title("Arm generating the trajectory (continuous workspace) - Trajectory " + str(tji))
plt.xlabel("x (m)")
plt.ylabel("y (m)")
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.savefig(os.getcwd()+"/"+base_dir+"/"+"continuous_workspace_trajectory_"+str(tji)+".pdf")
plt.show()

# %%
plt.figure()
plt.plot(t_mov,Joints[:,0],'bv-',label="Joint 1")
plt.plot(t_mov,Joints[:,1],'g.-',label="Joint 2")
plt.title("Joints (continuous workspace) - Trajectory " + str(tji))
plt.xlabel("time (s)")
plt.ylabel("angle (rad)")
plt.legend(loc=4)
plt.savefig(os.getcwd()+"/"+base_dir+"/"+"continouous_workspace_joints_"+str(tji)+".pdf")
plt.show()

# %%
# plt.figure()
# plt.plot(t_mov,Joints_ws[:,0],'bv-',label="Joint 1")
# plt.plot(t_mov,Joints_ws[:,1],'g.-',label="Joint 2")
# plt.title("Joints (discrete workspace)")
# plt.xlabel("time (s)")
# plt.ylabel("angle (rad)")
# plt.legend(loc=4)
# plt.savefig(os.getcwd()+"/"+base_dir+"/"+"discrete_workspace_joints_"+str(tji)+".pdf")
# plt.show()

# %%
# Joint's velocities
# teta1_d=numpy.concatenate((derivator(Joints[:,0],t_mov),[0]))
# teta2_d=numpy.concatenate((derivator(Joints[:,1],t_mov),[0]))
teta1_d=derivator(Joints_extended[:,0],t_mov_extended)
teta2_d=derivator(Joints_extended[:,1],t_mov_extended)

teta1_ws_d=derivator(Joints_ws_extended[:,0],t_mov_extended)
teta2_ws_d=derivator(Joints_ws_extended[:,1],t_mov_extended)

# %%
teta1_d[0],teta1_d[-2],teta2_d[0],teta2_d[-2],teta1_d.shape
# Out:
# (0.00014536431885980861, 0.0, 0.00016098705268863256, 0.0, (251,))

# %%
# # # Low-pass filtered joint's velocities
# teta1_d_adj = moving_average(teta1_d)
# teta2_d_adj = moving_average(teta2_d)

# %%
fig=plt.figure()
plt.subplot(211)
plt.plot(t_mov,teta1_d[:250],'bv-')
# plt.plot(t_mov,teta1_d_adj[:250],'g.-')
plt.title("Joint 1 angular velocities (continuous workspace) - Trajectory " + str(tji))
plt.ylabel("angular velocity (rad/s)")

plt.subplot(212)
plt.plot(t_mov,teta2_d[:250],'b.-')
# plt.plot(t_mov,teta2_d_adj[:250],'g.-')
plt.title("Joint 2 angular velocities (continuous workspace) - Trajectory " + str(tji))
plt.ylabel("angular velocity (rad/s)")
plt.xlabel("time (s)")
fig.subplots_adjust(hspace=.5) # Adjust the distance between subplots
plt.savefig(os.getcwd()+"/"+base_dir+"/"+"continuous_workspace_joints_veloc_"+str(tji)+".pdf")
plt.show()

# %%
# fig=plt.figure()
# plt.subplot(211)
# plt.plot(t_mov,teta1_ws_d[:250],'bv-')
# # plt.plot(t_mov,teta1_d_adj[:250],'g.-')
# plt.title("Joint 1 angular velocities (discrete workspace) - Trajectory " + str(tji))
# plt.ylabel("angular velocity (rad/s)")

# plt.subplot(212)
# plt.plot(t_mov,teta2_ws_d[:250],'b.-')
# # plt.plot(t_mov,teta2_d_adj[:250],'g.-')
# plt.title("Joint 2 angular velocities (discrete workspace) - Trajectory " + str(tji))
# plt.ylabel("angular velocity (rad/s)")
# plt.xlabel("time (s)")
# fig.subplots_adjust(hspace=.5) # Adjust the distance between subplots
# plt.savefig(os.getcwd()+"/"+base_dir+"/"+"discrete_workspace_joints_veloc_"+str(tji)+".pdf")
# plt.show()

# %%
teta1_d.shape
# Out:
# (251,)

# %%
# Joint's accelerations (with CONTINUOUS joint's velocities)
teta1_dd=derivator(teta1_d,t_mov_extended[:251])
teta2_dd=derivator(teta2_d,t_mov_extended[:251])

# Joint's accelerations (with DISCRETE joint's velocities)
teta1_ws_dd=derivator(teta1_ws_d,t_mov_extended[:251])
teta2_ws_dd=derivator(teta2_ws_d,t_mov_extended[:251])

# %%
teta1_dd[0],teta1_dd[-1],teta2_dd[0],teta2_dd[-1]
# Out:
# (0.43260256876731518, 0.0, 0.4790901233509004, 0.0)

# %%
fig=plt.figure()
plt.subplot(211)
plt.plot(t_mov,teta1_dd,'bv-')
plt.title("Joint 1 accelerations (continuous workspace) - Trajectory " + str(tji))
plt.ylabel("angular acceleration (rad/$s^2$)")

plt.subplot(212)
plt.plot(t_mov,teta2_dd,'b.-')
plt.title("Joint 2 accelerations (continuous workspace) - Trajectory " + str(tji))
plt.ylabel("angular acceleration (rad/$s^2$)")
plt.xlabel("time (s)")

fig.subplots_adjust(hspace=.5) # Adjust the distance between subplots
plt.savefig(os.getcwd()+"/"+base_dir+"/"+"continuous_workspace_joints_acc_"+str(tji)+".pdf")
plt.show()

# %%
# fig=plt.figure()
# plt.subplot(211)
# plt.plot(t_mov,teta1_ws_dd,'bv-')
# plt.title("Joint 1 accelerations (discrete workspace) - Trajectory " + str(tji))
# plt.ylabel("angular acceleration (rad/$s^2$)")

# plt.subplot(212)
# plt.plot(t_mov,teta2_ws_dd,'b.-')
# plt.title("Joint 2 accelerations (discrete workspace) - Trajectory " + str(tji))
# plt.ylabel("angular acceleration (rad/$s^2$)")
# plt.xlabel("time (s)")

# fig.subplots_adjust(hspace=.5) # Adjust the distance between subplots
# plt.savefig(os.getcwd()+"/"+base_dir+"/"+"discrete_workspace_joints_acc_"+str(tji)+".pdf")
# plt.show()

# %%
# # Joint's accelerations (with FILTERED joint's velocities)
# teta1_dd_f=derivator(teta1_d_adj,t_mov_extended[:251])
# teta2_dd_f=derivator(teta2_d_adj,t_mov_extended[:251])

# %%
# fig=plt.figure()
# plt.subplot(211)
# plt.plot(t_mov,teta1_dd_f,'b.-')
# plt.title("Joint 1 accelerations (with FILTERED joint's velocities) - Trajectory " + str(tji))

# plt.subplot(212)
# plt.plot(t_mov,teta2_dd_f,'b.-')
# plt.title("Joint 2 accelerations (with FILTERED joint's velocities) - Trajectory " + str(tji))

# fig.subplots_adjust(hspace=.5) # Adjust the distance between subplots
# plt.show()

# %%
#
# WITH CONTINUOUS JOINT'S VELOCITIES
#

# And generates a matrix with [teta1,teta2,teta1d,teta2d,teta1dd,teta2dd]
# Using this matrix I will generate the torques.
states_mov = numpy.array([[Joints[:,0][i],Joints[:,1][i],teta1_d[i],teta2_d[i],teta1_dd[i],teta2_dd[i]] for i in range(len(Joints[:,0]))])

#
# WITH DISCRETE JOINT'S VELOCITIES
#

# And generates a matrix with [teta1,teta2,teta1d,teta2d,teta1dd,teta2dd]
# Using this matrix I will generate the torques.
states_mov_ws = numpy.array([[Joints_ws[:,0][i],Joints_ws[:,1][i],teta1_ws_d[i],teta2_ws_d[i],teta1_ws_dd[i],teta2_ws_dd[i]] for i in range(len(Joints_ws[:,0]))])

# %%
#
# WITH FILTERED JOINT'S VELOCITIES
#

# And generates a matrix with [teta1,teta2,teta1d,teta2d,teta1dd,teta2dd]
# Using this matrix I will generate the torques.
# states_mov = numpy.array([[Joints[:,0][i],Joints[:,1][i],teta1_d_adj[i],teta2_d_adj[i],teta1_dd[i],teta2_dd[i]] for i in range(len(Joints[:,0]))])

# %%
# Applying the function to all lines of the states_mov matrix, I generate the torques matrix
T_mov=numpy.array([twojointarm_torques(states_mov[i], t_mov, aparams) for i in range(numpy.shape(states_mov)[0])])

# Applying the function to all lines of the states_mov matrix, I generate the torques matrix
T_mov_ws=numpy.array([twojointarm_torques(states_mov_ws[i], t_mov, aparams) for i in range(numpy.shape(states_mov_ws)[0])])

# %%
# Torques

plt.figure()
plt.plot(t_mov,T_mov[:,0],'bv-', label="Torques Joint 1")
plt.plot(t_mov,T_mov[:,1],'g.-', label="Torques Joint 2")
plt.title("Torques (continuous workspace) - Trajectory " + str(tji))
plt.xlabel("time (s)")
plt.ylabel("torque (Nm)")
plt.xlim(t_mov[0],t_mov[-1])
plt.legend()
plt.savefig(os.getcwd()+"/"+base_dir+"/"+"continuous_workspace_joints_torques_"+str(tji)+".pdf")
plt.show()

# %%
# # Torques

# plt.figure()
# plt.plot(t_mov,T_mov_ws[:,0],'bv-', label="Torques Joint 1")
# plt.plot(t_mov,T_mov_ws[:,1],'g.-', label="Torques Joint 2")
# plt.title("Torques (discrete workspace) - Trajectory " + str(tji))
# plt.xlabel("time (s)")
# plt.ylabel("torque (Nm)")
# plt.xlim(t_mov[0],t_mov[-1])
# plt.legend()
# plt.savefig(os.getcwd()+"/"+base_dir+"/"+"discrete_workspace_joints_torques_"+str(tji)+".pdf")
# plt.show()

# %%
# threshold_value=20

# T_teta1=T_mov[:,0]
# T_teta1[T_teta1>threshold_value]=threshold_value
# T_teta1[T_teta1<-threshold_value]=-threshold_value

# T_teta2=T_mov[:,1]
# T_teta2[T_teta2>threshold_value]=threshold_value
# T_teta2[T_teta2<-threshold_value]=-threshold_value

# T_mov_threshold=numpy.array([T_teta1,T_teta2]).T

# %%
# Here I calculate the states using the calculated torques, just to make sure it is working!
state = states_mov[0,[0,1,2,3]] # This is the initial state. The rest of the states will be generated dynamically 
                                # according to the input torques.
state_v2 = []
t = t_mov
torque = T_mov
for i in range(len(t)-1):
#     print "state:",state
    state = odeint_arms(twojointarm, state, [t[i], t[i+1]], aparams, torque[i])[1]
    state_v2.append(state)

state_v2=numpy.array(state_v2)

# %% [markdown]
# ## If the movements need big changes in the acceleration (torques) the time resolution can be too small to solve and the system deviates from the CONTINUOUS trajectory!

# %%
# Here I create the same animation and, if everything is working, this animation should be almost the same as the first one!
# %matplotlib inline
anim=animatearm_JS(state_v2,t_mov,aparams)
anim
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgZUXLWJOHDAGQFMEI">
#     <br>
#     <input id="_anim_sliderZUXLWJOHDAGQFMEI" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animZUXLWJOHDAGQFMEI.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animZUXLWJOHDAGQFMEI.slower()">&#8211;</button>
#     <button onclick="animZUXLWJOHDAGQFMEI.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZUXLWJOHDAGQFMEI.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZUXLWJOHDAGQFMEI.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZUXLWJOHDAGQFMEI.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animZUXLWJOHDAGQFMEI.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZUXLWJOHDAGQFMEI.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZUXLWJOHDAGQFMEI.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZUXLWJOHDAGQFMEI.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectZUXLWJOHDAGQFMEI" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgZUXLWJOHDAGQFMEI";
#     var slider_id = "_anim_sliderZUXLWJOHDAGQFMEI";
#     var loop_select_id = "_anim_loop_selectZUXLWJOHDAGQFMEI";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
# # import save_load_file as slf
# tji=0
# slf.save_to_file_gz(numpy.array([state_v2,torque]),"./"+base_dir+"/"+sim_set+"/States_Torques_movement"+str(tji)+".gzpickle")
# # slf.save_to_file_gz(numpy.array([states_mov[:,[0,1,2,3]],T_mov]),"./"+base_dir+"/"+sim_set+"/States_Torques_movement"+str(tji)+".gzpickle")

# %%
# states_mov.shape,T_mov.shape, state_v2.shape, torque.shape

# %%
# states_mov[:,[0,1,2,3]].shape

# %%
# To save the animation into a mp4 file:
# (this is not working on Ubuntu 12.04, I need to check if the codecs are installed properly)
# anim.save('2DoF_simulation_example.mp4', fps=15, extra_args=['-vcodec', 'libx264'])
# anim.save("./"+base_dir+"/"+sim_set+"/2Dof_animation_movement"+str(tji)+".mp4", fps=15, extra_args=['-vcodec', 'libx264'])
